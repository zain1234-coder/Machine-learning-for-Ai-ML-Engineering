# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model  import LogisticRegression
from sklearn.metrics import accuracy_score
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# ### Steps
# - 0. Preprocess + EDA + Feature Selection
# - 1. Extract input and output cols
# - 2. Scale the values
# - 3. Train test split
# - 4. Train the model
# - 5. Evaluate the model/model selection
# - 6. Deploy the model

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %% [markdown]
# # Preprocessing

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# # EDA

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'],label= 'Placed student')
plt.title("Distribution of Placed Student")
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.legend()
plt.show()

# %%
X = df[['cgpa','iq']]
Y  = df[['placement']]

# %%
Y.head()
# Out:
#    placement
# 0          1
# 1          0
# 2          0
# 3          1
# 4          0

# %%
X.head()
# Out:
#    cgpa     iq
# 0   6.8  123.0
# 1   5.9  106.0
# 2   5.3  121.0
# 3   7.4  132.0
# 4   5.8  142.0

# %%
x_train,x_test ,y_train,y_test =train_test_split(X,Y,test_size=0.1)

# %%
scalar = StandardScaler()

# %%
x_train = scalar.fit_transform(x_train)

# %%
x_test = scalar.transform(x_test)

# %% [markdown]
# # Model Training

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# c:\Users\zaina\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
plot_decision_regions(
    x_train,
    y_train.values.ravel(),
    clf=clf,
    legend=2
)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
