# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cars.csv")

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['brand'].value_counts(ascending=False)# Checking which brand has more value
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Ambassador          4
# Kia                 4
# MG                  3
# Daewoo              3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df['brand'].nunique() #Checking unique  brands has
# Out:
# 32

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# # One Hot Encoding Using pandas

# %%
pd.get_dummies(df , columns=['fuel' ,'owner'],dtype=int)
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000         0            1         0
# 1       Skoda     120000         370000         0            1         0
# 2       Honda     140000         158000         0            0         0
# 3     Hyundai     127000         225000         0            1         0
# 4      Maruti     120000         130000         0            0         0
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000         0            0         0
# 8124  Hyundai     119000         135000         0            1         0
# 8125   Maruti     120000         382000         0            1         0
# 8126     Tata      25000         290000         0            1         0
# 8127     Tata      25000         290000         0            1         0
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# # K-1 OHE Encoding (Removing first column) solving multicollinearity prob
#
# -- Pandas cannot remember the order of columns which mattters in ml So we alway use Sklearn to do Encoding if Our goal is to make ML Model

# %%
pd.get_dummies(df , columns=['fuel' ,'owner'],dtype=int,drop_first=True) # drop first removing first column
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
# ...

# %% [markdown]
# # OHE With Sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split( 
    df.iloc[:,0:4],
    df.iloc[: ,-1],
    test_size=0.2,
    random_state=0
)

x_train.shape , x_test.shape
# Out:
# ((6502, 4), (1626, 4))

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
OHE = OneHotEncoder(drop='first'  ,dtype = np.int32 ,sparse_output=False) # Sparse_output = false to stop making  sparse aarray if it was not given we need to use toarray to see sparse array

# %%
x_train_new = OHE.fit_transform(x_train[['fuel' , 'owner']]) #.toarray()  if sparse_output not use in OneHotEncoder()

# %%
x_test_new = OHE.transform(x_test[['fuel' , 'owner']])  #.toarray()  if sparse_Output not use in OneHotEncoder()

# %%
np.hstack((x_train[['brand' , 'km_driven']].values , x_train_new)).shape
# Out:
# (6502, 9)

# %% [markdown]
# # OneHotEncoding with Top Cat

# %%
count = df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold = 100

# %%
repl = count[count <= threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl ,'Uncomon') , dtype=np.int32).sample(5)
# Out:
#       BMW  Chevrolet  Ford  Honda  Hyundai  Mahindra  Maruti  Renault  Skoda  \
# 2078    0          0     0      0        0         0       0        0      0
# 3494    0          0     0      0        1         0       0        0      0
# 752     0          0     0      0        0         0       0        0      0
# 3356    0          0     0      0        0         0       0        0      0
# 4656    0          0     0      0        0         0       1        0      0
#
#       Tata  Toyota  Uncomon  Volkswagen
# 2078     0       0        1           0
# 3494     0       0        0           0
# 752      0       1        0           0
# 3356     0       0        0           1
# 4656     0       0        0           0
