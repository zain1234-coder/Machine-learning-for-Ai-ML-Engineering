# %%
import numpy as np
import pickle
import pandas as pd

# %%
import pickle

ohe_sex = pickle.load(open('models/ohe_sex.pkl', 'rb'))
ohe_Embarked = pickle.load(open('models/ohe_Embarked.pkl', 'rb'))
si_age = pickle.load(open('models/si_age.pkl', 'rb'))
si_Embarked = pickle.load(open('models/si_Embarked.pkl', 'rb'))
Clf = pickle.load(open("models/Clf.pkl" , 'rb'))

# %%
# Pclass / Gender / age / sibSp / Parch / Fare / Embarked 
test_input = np.array([2 , 'male' , 31.0 , 0 ,0 ,10.5 , 'S'] , dtype=object) .reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# c:\Users\zaina\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_embark = ohe_Embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embark) ,axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %%
Clf.predict(test_input_transformed)
# Out:
# array([1])
