# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd

# %%
x,y = load_diabetes(return_X_y=True)

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size= 0.2 , random_state= 42)

# %%
Rd = Ridge(alpha = 0.1 , solver= 'cholesky')

# %%
Rd.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1, solver='cholesky')

# %%
y_pred = Rd.predict(x_test)

# %%
print(r2_score(y_test , y_pred),'\n')

print ("Slope \n",Rd.coef_,'\n')
print( "Intercept\n", Rd.intercept_)
# Out:
# 0.46085219464119254
#
# Slope
#  [  42.85566976 -205.49431899  505.08903304  317.0932049  -108.50026183
#   -86.23673333 -190.36318008  151.70708637  392.28931896   79.9081772 ]
#
# Intercept
#  151.45857456679613

# %% [markdown]
# The reason of using [0][0]=0 is that because in our metrix W the first term is basically intercept not slope and we have to multiply Lambda with only slopes.
# Thats why first term became zero and lambda is multiplied with only slopes.

# %%
class My_Ridge :
    def __init__(self , alpha=0.01):
        self.m = None
        self.b = None
        self.alpha = alpha

    def fit(self ,x_train,y_train):
        x_train =  np.insert(x_train ,0 ,1, axis=1)
        I = np.identity(x_train.shape[1]) #I = identity matrix of n*1
        I[0][0] = 0 # make identity matrix like that becuse ols use this   # 0 0 0
                                                                           # 0 1 0
                                                                           # 0 0 1
                    
        result = np.linalg.inv(np.dot(x_train.T , x_train ) + self.alpha * I).dot(x_train.T).dot(y_train)
        self.b = result[0]
        self.m = result[1:]

        print("slope",self.m )
        print("Intercept" , self.b)

    def predict(self,x_test):
        return np.dot(x_test,self.m) + self.b

# %%
MY = My_Ridge(alpha=0.1)

# %%
MY.fit(x_train,y_train)
# Out:
# slope [  42.85566976 -205.49431899  505.08903304  317.0932049  -108.50026183
#   -86.23673333 -190.36318008  151.70708637  392.28931896   79.9081772 ]
# Intercept 151.45857456679607

# %%
yy = MY.predict(x_test)

# %%
print(r2_score(y_test,yy))
# Out:
# 0.46085219464119254
