# %% [markdown]
# <div align="center">
#
# <table>
# <tr>
# <td><p>b = 120 , m = -100</p>
# <img src="animation4.gif" width="400"></td>
# <td>x-axis = epochs , y-axis = loss</p>
# <img src="animation5.gif" width="400"></td>
# </tr>
# <tr>
# <td> <p>x-axis = epoch , y-axis = b</p>
# <img src="animation6.gif" width="400"></td>
# <td><p>x-axis = epoch , y-axis = m</p>
# <img src="animation7.gif" width="400"></td>
# </tr>
# <tr>
# <td><p>
# x-axis = m , y-axis = b</p>
# <img src="animation8.gif" width="400"></td>
# <td><img src="animation9.gif" width="400"></td>
# </tr>
# </table>
#
# </div>
