# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df= pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(x = df['cgpa'] , y = df['package'])
plt.ylabel('Package-Lack-Per-Anum')
plt.xlabel("cgpa")
plt.show()

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y ,test_size=0.2 , random_state=2)

# %%
Linear_reg = LinearRegression()
Linear_reg.fit(x_train ,y_train)
# Out:
# LinearRegression()

# %%
Linear_reg.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\zaina\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
x_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %% [markdown]
# # Checking which line our linear regression makes

# %%
x_plot = x_train.sort_values('cgpa')

plt.scatter(df['cgpa'], df['package'])

plt.plot(
    x_plot['cgpa'],
    Linear_reg.predict(x_plot),
    color='red'
)

plt.ylabel('Package-Lakh-Per-Annum')
plt.xlabel('CGPA')
plt.show()

# %% [markdown]
# # Checking  which m and b is takein by algorithm

# %%
m = Linear_reg.coef_  # For Slope
m
# Out:
# array([0.55795197])

# %%
b = Linear_reg.intercept_ # for b ,
b
# Out:
# np.float64(-0.8961119222429144)

# %%
# How We are prediction
# we know  line eq is y = mx + b
# want to predict student package with 5.5 then
y =   m*6.5 + b
y
# Out:
# array([2.73057591])
