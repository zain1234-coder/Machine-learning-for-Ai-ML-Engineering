# %%
import pandas as pd
from sklearn.datasets import load_diabetes
import numpy as np

# %%
x,y = load_diabetes(return_X_y=True) #Sklearn give this in numpy array by splitting both x and y

# %%
x.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 , random_state=2)

# %%
print((x_train.shape ,"\n", x_test.shape))
# Out:
# ((353, 10), '\n', (89, 10))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print("r2_score is" , r2_score(y_test , y_pred))
# Out:
# r2_score is 0.439933866156897

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254167)

# %% [markdown]
# # **Creating our own Multiple Linear Reg**

# %%
class Multiple_reg:
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
    def fit(self,x_train ,y_train):
        x_train = np.insert(x_train , 0 , 1 ,axis=1)

        # Applying Coef Formula(Our Main Equation)

        beta = np.linalg.inv(np.dot(x_train.T,x_train )).dot(x_train.T).dot(y_train)

        self.intercept_ = beta[0]
        self.coef_ = beta[1:]

        

    def predict(self , x_test):
        return np.dot(x_test,self.coef_) + self.intercept_

# %%
MR = Multiple_reg()

# %%
MR.fit(x_train ,y_train)

# %%
y_pred = MR.predict(x_test)

# %%
print("R2Score" ,r2_score(y_test , y_pred))
# Out:
# R2Score 0.4399338661568961

# %%
MR.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
MR.intercept_
# Out:
# np.float64(151.8833100525417)

# %% [markdown]
# # **Testing it on 1d Data**

# %%
df1 = pd.read_csv("Placement.csv")

# %%
df1.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x = df1.iloc[:,0:1]
y = df1.iloc[:,-1]

# %%
x_train , x_test , y_train ,y_test = train_test_split(x ,y ,test_size=0.2 , random_state=2)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
y_train.shape
# Out:
# (160,)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.780730147510384

# %% [markdown]
# # **Compareing with my model**

# %%
Mr  = Multiple_reg()

# %%
Mr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.780730147510384
