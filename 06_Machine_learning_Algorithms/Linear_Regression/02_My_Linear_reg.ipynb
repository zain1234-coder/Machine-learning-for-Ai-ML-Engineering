# %% [markdown]
# # **Creating my own Simple Linear Regression  model**

# %%
class My_LR:
    def __init__(self):
        self.m = None
        self.b = None

    def fit(self , x_train , y_train):  # In linear regresion training a model mean calculating value of m and b
        
        num = 0
        den = 0 

        for i in range(x_train.shape[0]) :
            num = num + ((x_train[i] - x_train.mean()) * (y_train[i] - y_train.mean()))
            den = den + ((x_train[i] - x_train.mean())*(x_train[i] - x_train.mean()))

        self.m =  num / den 

        self.b = y_train.mean() - ( self.m * x_train.mean())
        print("m is  " , self.m)
        print("b is " ,self.b)

    def predict(self , x_test):
        return self.m * x_test + self.b

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("placement.csv")

# %%
x = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train,x_test , y_train , y_test = train_test_split(x,y , test_size=0.2 , random_state=2)

# %%
x_train.shape
# Out:
# (160,)

# %%
lr = My_LR()

# %%
lr.fit(x_train ,y_train)
# Out:
# m is   0.5579519734250721
# b is  -0.8961119222429152

# %%
lr.predict(x_test[0])
# Out:
# np.float64(3.891116009744203)
